# %% [markdown]
# <a href="https://colab.research.google.com/github/pavanreddy8318/Java-Programing/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Create a variable to store your name, age, and percentage. Print them in one line.
name=input("enter your name:")
age=input("enter your age:")
percentage=input("enter your percentage:")
print("hello,my name "+name  +age  +percentage)
# Out:
# enter your name:pavan
# enter your age:20
# enter your percentage:100
# hello,my name pavan20100

# %%
#Assign the same value 100 to three different variables in a single line.
a=b=c=100
print(a,b,c)
# Out:
# 100 100 100

# %%
#Swap two variables without using a third variable.
a=input("enter a value:")
b=input("enter b value:")
a,b=b,a
print("a=",a)
print("b=",b)
# Out:
# enter a value:10
# enter b value:20
# a= 20
# b= 10

# %%
#Assign an integer value and then change it to a string. Print the type before and after.
value=1234
print(type(value))
value=str(value)
print(type(value))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#Create a variable x = 10. Increase its value by 5 using an assignment operator.
x=10
x+=5
print(x)
# Out:
# 15

# %%
#SECTION 2: Data Types (Identify & Predict Output)
#Identify the data type of each:
a = 10
b = 10.5
c = "Python"
d = True
e = 3 + 4j
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
x = "10"
y = 5
print(x * y)
# Out:
# 1010101010

# %%
a = 5
b = 2
print(a / b)
print(a // b)
# Out:
# 2.5
# 2

# %%
#Check whether a variable num = 25 is of type int using a built-in function.
num = 25
print(type(num) == int)
# Out:
# True
